# %% [markdown]
# Q01 - Faça um programa que peça a idade da pessoa e imprima se ela é maior ou menor de 18 anos.

# %%
idade = int(input('Qual é a sua idade? '))

if 0 < idade < 18:
  print(f'Você é menor de 18 anos.')
elif idade >= 18:
  print(f'Você é maior de 18 anos.')
else:
  print('Informe uma idade válida.')
# Out:
# Qual é a sua idade? -12
# Informe uma idade válida.

# %% [markdown]
# Q02 - Faça um programa que peça um número e mostre se ele é positivo ou negativo.

# %%
numero = float(input('Informe um número qualquer: '))

if numero == 0:
  print('Zero é um número neutro.')
elif numero > 0:
  print('O número é positivo.')
else:
  print('O número é negativo.')
# Out:
# Informe um número qualquer: 343.32
# O número é positivo.

# %% [markdown]
# Q03 - Faça um programa que peça dois números e mostre o maior deles.

# %%
num1 = float(input('Informe um número:'))
num2 = float(input('Informe outro número:'))

if num1 == num2:
  print('Os número são iguais.')
elif num1 > num2:
  print(f'O {num1} é maior número informado.')
else:
  print(f'O {num2} é maior número informado.')
# Out:
# Informe um número:-3
# Informe outro número:0
# O 0.0 é maior número informado.

# %% [markdown]
# Q04 - Escreva um programa que peça a nota de 3 provas de um aluno e mostre se ele passou ou não de ano.
#
# Obs.: O aluno irá passar de ano se a média das suas notas for maior ou igual a 6 (média é a soma das notas dividido pelo número de provas).

# %%
nota1 = float(input('Informe a primeira nota: '))
nota2 = float(input('Informe a segunda nota: '))
nota3 = float(input('Informe a terceira nota: '))

media = (nota1 + nota2 + nota3) / 3

if media >= 6:
  print('A média do aluno é', media, ' - O aluno passou de ano.')
else:
  print('A média do aluno é', media, ' - O aluno não passou de ano.')
# Out:
# Informe a primeira nota: 8
# Informe a segunda nota: 9
# Informe a terceira nota: 7
# A média do aluno é 8.0  - O aluno passou de ano.

# %% [markdown]
# Q05 - Faça um programa que mostre uma questão de múltipla escolha com 5 opções (letras a, b, c, d, e). Sabendo a resposta certa, o programa deve receber a opção do usuário e informar a letra que o usuário marcou e se a resposta está certa ou errada.

# %%
resp = input('''Assinale a alternativa que corresponde à voz ativa da sentença a seguir: “The 1994 cup was hosted by the United States.”
A) The United States hosted the 1994 Cup.
B) The United States will host the 1994 Cup.
C) The United States have hosted the 1994 Cup.
D) The United States had hosted the 1994 Cup.
E) The United States will have hosted the 1994 Cup.\n''')

resp = resp.upper()

if resp == 'A':
  print(f'Você acertou, a resposta correta é alternativa A.')
else:
  print(f'A alternativa {resp} está errada, a resposta correta é alternativa A.')
# Out:
# Assinale a alternativa que corresponde à voz ativa da sentença a seguir: “The 1994 cup was hosted by the United States.”
# A) The United States hosted the 1994 Cup.
# B) The United States will host the 1994 Cup.
# C) The United States have hosted the 1994 Cup.
# D) The United States had hosted the 1994 Cup.
# E) The United States will have hosted the 1994 Cup.
# c
# A alternativa C está errada, a resposta correta é alternativa A.

# %% [markdown]
# Q06 - Vamos fazer um programa para verificar quem é o assassino de um crime. Para descobrir o assassino, a polícia faz um pequeno questionário com 5 perguntas onde a resposta só pode ser sim ou não:
#
# a. Mora perto da vítima?
#
# b. Já trabalhou com a vítima?
#
# c. Telefonou para a vítima?
#
# d. Esteve no local do crime?
#
# e. Devia para a vítima?
#
# Cada resposta sim dá um ponto para o suspeito. A polícia considera que os suspeitos com 5 pontos são os assassinos, com 4 a 3 pontos são cúmplices e 2 pontos são apenas suspeitos, necessitando outras investigações. Valores abaixo de 1 são liberados.

# %%
respAfirmativa = 0

mora = input('Mora perto da vítima? (S/N) ')
trabalha = input('Já trabalhou com a vítima? (S/N) ')
telefona = input('Telefonou para a vítima? (S/N) ')
local = input('Esteve no local do crime? (S/N) ')
devia = input('Devia para a vítima? (S/N)')

if (mora == 'S') or (mora == 's'):
  respAfirmativa += 1

if (trabalha == 'S') or (trabalha == 's'):
  respAfirmativa += 1

if (telefona == 'S') or (telefona == 's'):
  respAfirmativa += 1

if (local == 'S') or (local == 's'):
  respAfirmativa += 1

if (devia == 'S') or (devia == 's'):
  respAfirmativa += 1

if respAfirmativa == 5:
  print('Assassino')
elif 3 <= respAfirmativa <= 4:
  print('Cúmplice')
elif respAfirmativa == 2:
  print('Suspeito')
else:
  print('Inocente')
# Out:
# Mora perto da vítima? (S/N)s
# Já trabalhou com a vítima? (S/N)s
# Telefonou para a vítima? (S/N)s
# Esteve no local do crime? (S/N)n
# Devia para a vítima? (S/N)n
# Cúmplice

# %% [markdown]
# Q07 - Faça um programa em que o usuário tem que adivinhar o número escolhido pelo computador. O computador deve sortear um número inteiro de 1 a 5 e pedir para o usuário tentar descobrir qual o número sorteado. Após o usuário digitar sua resposta, o programa deve dizer se ele acertou ou não. Dica: para sortear um número, você precisará utilizar a biblioteca random.

# %%
import random

numSorteado = random.randint(1,5)

num = int(input('Informe um número de 1 a 5: '))

if num == numSorteado:
  print(f'Você acertou. \nNúmero sorteado: {numSorteado} \nNúmero escolhido: {num}')
else:
  print(f'Você errou. \nNúmero sorteado: {numSorteado} \nNúmero escolhido: {num}')
# Out:
# 3
# Informe um número de 1 a 5: 3
# Você acertou.
# Número sorteado: 3
# Número escolhido: 3

# %% [markdown]
# Q08 - Vamos fazer um radar eletrônico de velocidade. Faça um programa que leia a velocidade de um carro, e diga se ele está acima ou não da velocidade permitida de 50 km/h. Se o carro estiver acima da velocidade, o programa deve imprimir que o motorista ultrapassou a velocidade permitida e recebeu uma multa num determinado valor. Para calcular o valor da multa, considere que para cada quilômetro acima da velocidade permitida, o motorista deve pagar 10 reais.

# %%
velCarro = int(input('Informe a velocidade do carro: '))

if velCarro > 50:
  multa = (velCarro - 50) * 10
  print(f'Você ultrapassou a velocidade permitida. Sua multa será de R$ {multa}')
else:
  print('Velocidade dentro do permitido.')
# Out:
# Informe a velocidade do carro: 70
# Você ultrapassou a velocidade permitida. Sua multa será de R$ 200

# %% [markdown]
# Q09 - Com a recomendação que as pessoas fiquem em casa e evitem aglomerações como medida pra frear a contaminação pelo coronavírus, como saber quando devemos procurar um hospital? Faça um programa que pergunte os sintomas que a pessoa apresenta e responda se ela deve ou não procurar um hospital.
#
# Sintomas: a. Você tem febre persistente? b. Você tem dificuldade para respirar?
#
# A resposta do programa deve seguir a seguinte tabela:
#
# A	B	Resultado
# Sim	Não	Fique em casa
# Não	Sim	Fique em casa
# Não	Não	Fique em casa
# Sim	Sim	Procure um hospital

# %%
febre = False
respiracao = False

sintoma1 = input('Você tem febre persistente? (S/N) ')
sintoma2 = input('Você tem dificuldade para respirar? (S/N) ')

if (sintoma1 == 'S') or (sintoma1 == 's'):
  febre = True
if (sintoma2 == 'S') or (sintoma2 == 's'):
  respiracao = True

if febre and respiracao:
  print('Procure um hospital.')
else:
  print('Fique em casa.')
# Out:
# Você tem febre persistente? (S/N) n
# Você tem dificuldade para respirar? (S/N) n
# Fique em casa.
